# %% [markdown]
# <a href="https://colab.research.google.com/github/quantum-intelligence/computational-physics/blob/main/Intro_to_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Computational Physics
# ###PHYS 4810
# Trevor David Rhone

# %% [markdown]
# ### Type Conversion

# %%
x = 1    # int
y = 2.8  # float
z = 1j   # complex

#convert from int to float:
a = float(x)

#convert from float to int:
b = int(y)

#convert from int to complex:
c = complex(x)

print(a)
print(b)
print(c)

print(type(a))
print(type(b))
print(type(c))
# Out:
# 1.0
# 2
# (1+0j)
# <class 'float'>
# <class 'int'>
# <class 'complex'>

# %% [markdown]
# ## Booleans

# %%
print(10 > 9)
print(10 == 9)
print(10 < 9)
# Out:
# True
# False
# False

# %%
a = 200
b = 33

if b > a:
  print("b is greater than a")
else:
  print("b is not greater than a")

# %% [markdown]
# Operators

# %% [markdown]
# Try it: Consider a function/script that takes two integers x1 and x2. If they are equal, then add them.  If they are the different then subtract them. Write a script that accomplishes this using logical operators. Try diferenv t values for x1 and x2.

# %%
# declare x1, x2 here. Update the values as desired.
x1 = 0
x2 = 0

# check if x1 and x2 are the same:


# check if x1 and x2 are different:

# %% [markdown]
# ### if else statements

# %%
# use if else statement:
# declare a value for x1
# decalre a value for x2
# if x1 is not equal x2 then print this string: "these values are not equal"

# %% [markdown]
# # Python loops
# - While loops
# - For loops

# %% [markdown]
# ### While loops
# use a variable "counter" that initialized at 10 to count down to 0. Print each value for counter.

# %% [markdown]
# ### For loops
# print items in the following list:

# %%
physics = ["electromagnetic theory","quantum physics", "computational physics", "classical mechanics"]

# %% [markdown]
# ### Python Functions
# syntax:
#
# <code>
# def myfunction(arg1, arg2): <br>
#      &nbsp  """ comment line """ <br>
#      &nbsp  code here <br>
#      &nbsp  return value <br>
# </code>

# %%
# define a function "my_function" that that prints "Hello World"

# %%
# Define a function "my_other_function" that takes two numbers as parameters and returns the sum

# %% [markdown]
# ## Global and local scope

# %%
x = 300
def myfunc():
   print(x)

myfunc()
print(x)

# declare a local variable inside a function and print the contents...
# Out:
# 300
# 300

# %% [markdown]
# ### Python Modules
# Many python modules exists which make python a very powerful programming platform.

# %%
# use the 'time' module to time a function. Chande the task between tic and toc to see what takes more time to run
import time
tic = time.process_time()
print("--- do something that takes time ---")
toc = time.process_time()
time_taken = toc - tic
print("time_taken: ", time_taken)
# Out:
# --- do something that takes time ---
# time_taken:  0.0002065820000005658

# %% [markdown]
# ### Python Arrays

# %%
# play with built-in python arrays
import array as arr

a = arr.array('u',['s','2','3'])
#print different elements:
a[0]

#change the data type:
# Out:
# 's'

# %%
# numpy is very powerful and can be used to create versatile arrays
import numpy as np

# %%
x = np.asarray([1,2,3])
# explore x by printing the data structure type, the values, the ith value, etc.
# print(type(x))
# print(x)
# print(x[0])

# %% [markdown]
# ### Pandas

# %%
import pandas as pd

# %%
#@title
#create dataset [hidden]
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0,15,100)
y = np.sin(x) + np.random.rand(100)
df_hide = pd.DataFrame()
df_hide['x'] = x
df_hide['y'] = y
df_hide.to_csv('data.csv')
# plt.scatter(x,y)

# %% [markdown]
# load data.csv into a pandas dataframe and print some of the results. Uncomment and run some of the code.

# %%
df = pd.read_csv('data.csv')
# print(df.columns)
# print(df.shape)
# print(df.head())

# %% [markdown]
# ### Matplotlib and plotting in python

# %%
import matplotlib.pyplot as plt

# plt.scatter(df['x'],df['x'])
# modify the above function to plot the x and y columns of the dataframe
# do a histogram plot of the y values.

# %%
# add a title, axis labels and change the color, size, transparency of the markers

# %% [markdown]
# ### Seaborn example
# https://seaborn.pydata.org/examples/different_scatter_variables.html

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Load the example diamonds dataset
diamonds = sns.load_dataset("diamonds")

# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
sns.scatterplot(x="carat", y="price",
                hue="clarity", size="depth",
                palette="ch:r=-.2,d=.3_r",
                hue_order=clarity_ranking,
                sizes=(1, 8), linewidth=0,
                data=diamonds, ax=ax)
plt.show()

# %% [markdown]
# ### Plotly example

# %%
import plotly.express as px
df = px.data.iris()
fig = px.scatter_3d(df, x='sepal_length', y='sepal_width', z='petal_width',
              color='species')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e48ae371-4740-4f32-9985-8da11e262404" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e48ae371-4740-4f32-9985-8da11e262404")) {
#                     Plotly.newPlot(
#                         'e48ae371-4740-4f32-9985-8da11e262404',
# ...
